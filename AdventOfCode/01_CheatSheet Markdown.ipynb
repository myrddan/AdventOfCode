# %% [markdown]
# <img src="./images/logo-jupiter.png" />
#
#
# # Cheatsheet Markdown pour jupyter
#
# Jupyter Notebook est un environnement interactif open-source qui permet de créer et partager des documents combinant du code exécutable (Python, R, etc.), des visualisations, du texte formaté en Markdown et des équations, idéal pour l'analyse de données, la recherche et l'enseignement.
#
# Le Markdown est un langage de balisage léger qui permet de formater du texte de manière simple et intuitive, idéal pour rédiger des documents structurés (comme des README, des notes ou des pages web) sans utiliser de code HTML complexe.

# %% [markdown]
# # Titres (Headings)
#    Le nombre de # en début de ligne va déterminer le niveau du titre :
# - # Pour les titres
# ```markdown
# # Pour les titres
# ```
# - ## Pour les sous-titres
# ```markdown
# ## Pour les sous-titres
# ```
# - ### pour les parties
# ```markdown
# ### pour les parties
# ```
# - #### pour les sous-parties
#
# ```markdown
# #### for 4th level subheadings
# ```
#
# # Formatage (Emphasis)
#
# Formatage du texte :
# - **Mise en gras**:
#    ```__gras__ or **gras**```
# - *Mise en italic* :
#    ``` _italic_ or *italic*```
# - Font monospace :
#    ``` `monospace` ```
#    -
#
# # Ligne séparatrice
# ----
#     ----

# %% [markdown]
# # Les listes
#
# ## A puce
#
# Ajouter + ou - pour créer la liste, vous pouvez gérer les sous-niveau avec des espaces.
#
# - Main bullet point
#   -  Sub bullet point 2 spaces
#     - Sub bullet point 4 spaces or tab
# ```
# - Main bullet point
#   -  Sub bullet point 2 spaces
#     - Sub bullet point 4 spaces or tab
# ```
#
# ## Ordonné
#
# Ajouter 1. ou 1) pour créer la liste, vous pouvez gérer les sous-niveaux avec des espaces.
#
# 1. Main point
#     1) Sub point
#     1) Sub point
#
# ```
# 1. Main point
#     1) Sub point
#     1) Sub point
#
# ```

# %% [markdown]
# # Citations
#
#
# Une belle citation d'Héraclite :
# > On ne se baigne jamais deux fois dans le même fleuve.\
#
# ```markdown
# Une belle citation d'Héraclite :
# > On ne se baigne jamais deux fois dans le même fleuve.\
# ```
#
# # Code
#
# Vous pouvez encadrer le code avec ``` <alt Gr + 7> ou ajouter 4 espaces :
# ```
# def f(x):
#     """a docstring"""
#     return x**2
# ```
#
#     ```
#     def f(x):
#         """a docstring"""
#         return x**2
#     ```

# %% [markdown]
# # Mise en évidence
#
# ## Info (Bleu)
#
# ```markdown
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>
#
# ## Succès (vert)
#
# ```markdown
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>
# ```
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>
#
# ## Warning (Jaune)
#
# ```markdown
# <div class="alert alert-block alert-warning">
# <b>&#9888Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>
# ```
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>
#
# ## Erreur (rouge)
#
# ```markdown
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>
# ```
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# # Image
#
# ## Lien interne
#
# <img src="./images/logo-jupiter.png" />
#
#     <img src="./images/logo-jupiter.png" />
#
# ## Lien externe
#
# <img src="https://www.developpez.com/template/images/logo-dvp-h55.png" />
#
#     <img src="https://www.developpez.com/template/images/logo-dvp-h55.png" />

# %% [markdown]
# ---
#
# Symboles unicode
#
# ---
#
# Vous pouvez copier les symboles unicodes trouvable sur internet : https://symbl.cc/en/emoji/symbols/
#
#
# ✅,&#9989; &#10004; ou &check;
#
# ❌,&#10060;
#
# ⚠️,&#9888;&#65039;
#
# ❗,&#10071;
#
# ❓,&#10067;
#
# ⭕, &#11093;
#
# ⛔, &#9940;
#
# &#1037598940; 😱 💀
#
# ```markdown
# ✅,&#9989; &#10004; ou &check;
# ❌,&#10060;
# ⚠️️,&#9888;&#65039;
# ❗,&#10071;
# ❓,&#10067;
# ⭕, &#11093;
# ⛔, &#9940;
# ```

# %% [markdown]
# ```markdown
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}
# ```
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|
